# %%
import exg
import ohta
import exgexr
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

import cv2

# %%
image = np.array(Image.open('frame_10.jpg'))
#image = cv2.GaussianBlur(image,(21,21),20)

# %%
plt.imshow(image)

# %%
mask = exg.hard_exg_th(image)

# %%
plt.imshow(mask)

# %%
mask2 = ohta.ohta_otsu(image)

# %%
plt.imshow(mask2)

# %%
mask3 = exg.exg_th(image)

# %%
plt.imshow(mask3)

# %%
mask4 = exgexr.exgexr(image)

# %%
plt.imshow(mask4)
